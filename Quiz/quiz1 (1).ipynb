# %% [markdown]
# # For section C2

# %% [markdown]
# ## Q1 (NumPy shapes)
#
# ```
# Given
#
# import numpy as np
# X = np.random.randn(100, 3)
# w = np.array([1.0, 2.0, 3.0])
# y_hat = X @ w
#
# ```
#
# 1.	What is the shape of X, w, and y_hat? Print the shapes to show.

# %% [markdown]
# ## Q2 (Feature-wise reductions)
#
# ```
#
# Given X with shape (n_samples, n_features):
#
# X = np.random.randn(50, 4)
#
# ```
#
# Write code to compute:
#
# 1.	Mean per feature
# 2.	Standard deviation per feature

# %% [markdown]
# ## Q3 (Pandas: identify missing values)
#
# Given a pandas DataFrame df, write code to print:
#
# 1.	Missing value count per column/attribute/feature.

# %% [markdown]
# # For section C1

# %% [markdown]
# ## Q1 (Pandas: fillna with different values per column)
#
# Suppose df has columns: temperature, windspeed, event.
# Create the dataframe and write a fillna call that fills:
#
# 	•	temperature with 0
# 	•	windspeed with the median windspeed
# 	•	event with "No Event"

# %% [markdown]
# ## Q2. Create:
#
# 	•	a (4,5) array of zeros
# 	•	a (3,3) identity matrix
# 	•	a length-10 array from 0 to 9

# %% [markdown]
# ## Q3
#
# Given
#
# ```
# import numpy as np
# A = np.array([[5, 2, 9],
#               [1, 7, 3],
#               [8, 4, 6]])
# ```
#
# 1.	the element 7
# 2.	the first row
# 3.	the last column
# 4.	the submatrix [[2,9],[7,3]]
